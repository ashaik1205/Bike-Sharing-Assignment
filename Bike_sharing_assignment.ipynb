# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import calendar
from sklearn.metrics import r2_score
from math import sqrt

# %%
#copied to googledrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#loading dataset from drive
df=pd.read_csv("/content/drive/MyDrive/day.csv")

# %%
df.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0        1  01-01-2018       1   0  ...  10.749882     331         654   985
# 1        2  02-01-2018       1   0  ...  16.652113     131         670   801
# 2        3  03-01-2018       1   0  ...  16.636703     120        1229  1349
# 3        4  04-01-2018       1   0  ...  10.739832     108        1454  1562
# 4        5  05-01-2018       1   0  ...  12.522300      82        1518  1600
#
# [5 rows x 16 columns]

# %%
df.shape
# Out:
# (730, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
df.describe()
# Out:
#           instant      season  ...   registered          cnt
# count  730.000000  730.000000  ...   730.000000   730.000000
# mean   365.500000    2.498630  ...  3658.757534  4508.006849
# std    210.877136    1.110184  ...  1559.758728  1936.011647
# min      1.000000    1.000000  ...    20.000000    22.000000
# 25%    183.250000    2.000000  ...  2502.250000  3169.750000
# 50%    365.500000    3.000000  ...  3664.500000  4548.500000
# 75%    547.750000    3.000000  ...  4783.250000  5966.000000
# max    730.000000    4.000000  ...  6946.000000  8714.000000
#
# [8 rows x 15 columns]

# %% [markdown]
# Checking for Null values

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
plt.figure(figsize = (25,25))
sns.pairplot(data=df,vars=['cnt', 'temp', 'atemp', 'hum','windspeed'])
plt.show()

# %% [markdown]
# Checking for duplicate records

# %%
df.shape
# Out:
# (730, 16)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (730, 16)

# %%
plt.figure(figsize=(15, 15))
plt.subplot(4,2,1)
sns.boxplot(x = 'season', y = 'cnt', data = df)
plt.subplot(4,2,2)
sns.boxplot(x = 'yr', y = 'cnt', data = df)
plt.subplot(4,2,3)
sns.boxplot(x = 'mnth', y = 'cnt', data = df)
plt.subplot(4,2,4)
sns.boxplot(x = 'holiday', y = 'cnt', data = df)
plt.subplot(4,2,5)
sns.boxplot(x = 'weekday', y = 'cnt', data = df)
plt.subplot(4,2,6)
sns.boxplot(x = 'weathersit', y = 'cnt', data = df)
plt.subplot(4,2,7)
sns.boxplot(x = 'workingday', y = 'cnt', data =df)
plt.show()

# %%
df.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0        1  01-01-2018       1   0  ...  10.749882     331         654   985
# 1        2  02-01-2018       1   0  ...  16.652113     131         670   801
# 2        3  03-01-2018       1   0  ...  16.636703     120        1229  1349
# 3        4  04-01-2018       1   0  ...  10.739832     108        1454  1562
# 4        5  05-01-2018       1   0  ...  12.522300      82        1518  1600
#
# [5 rows x 16 columns]

# %%
df['mnth'] = df['mnth'].apply(lambda x: calendar.month_abbr[x])
df.season = df.season.map({1: 'Spring',2:'Summer',3:'Fall',4:'Winter'})
df.weathersit = df.weathersit.map({1:'Clear',2:'Mist & Cloudy', 
                                             3:'Light Snow & Rain',4:'Heavy Snow & Rain'})
df.weekday = df.weekday.map({0:"Sunday",1:"Monday",2:"Tuesday",3:"Wednesday",4:"Thrusday",5:"Friday",6:"Saturday"})

# %%
df.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual registered   cnt
# 0        1  01-01-2018  Spring   0  ...  10.749882     331        654   985
# 1        2  02-01-2018  Spring   0  ...  16.652113     131        670   801
# 2        3  03-01-2018  Spring   0  ...  16.636703     120       1229  1349
# 3        4  04-01-2018  Spring   0  ...  10.739832     108       1454  1562
# 4        5  05-01-2018  Spring   0  ...  12.522300      82       1518  1600
#
# [5 rows x 16 columns]

# %%
df.shape
# Out:
# (730, 16)

# %%
Dummy_variables = df[['season','mnth','weekday','weathersit']]
Dummy_variables= pd.get_dummies(Dummy_variables,drop_first=True )

# %%
df = pd.concat([Dummy_variables,df],axis = 1)

# %%
df.head()
# Out:
#    season_Spring  season_Summer  season_Winter  ...  casual  registered   cnt
# 0              1              0              0  ...     331         654   985
# 1              1              0              0  ...     131         670   801
# 2              1              0              0  ...     120        1229  1349
# 3              1              0              0  ...     108        1454  1562
# 4              1              0              0  ...      82        1518  1600
#
# [5 rows x 38 columns]

# %% [markdown]
# Dropping the Original columns of dummy variables

# %%
df.drop(['season', 'mnth', 'weekday','weathersit'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    season_Spring  season_Summer  season_Winter  ...  casual  registered   cnt
# 0              1              0              0  ...     331         654   985
# 1              1              0              0  ...     131         670   801
# 2              1              0              0  ...     120        1229  1349
# 3              1              0              0  ...     108        1454  1562
# 4              1              0              0  ...      82        1518  1600
#
# [5 rows x 34 columns]

# %%
plt.figure(figsize = (50, 35))
sns.heatmap(df.corr(), annot = True, cmap="Blues")
plt.show()

# %% [markdown]
# Drropping the variables which have high correaltion between them i.e, which have correlation more than 0.7

# %%
df_2=df.drop(columns=['instant','atemp','registered','dteday'],axis=1)

# %%
df_2.head()
# Out:
#    season_Spring  season_Summer  season_Winter  ...  windspeed  casual   cnt
# 0              1              0              0  ...  10.749882     331   985
# 1              1              0              0  ...  16.652113     131   801
# 2              1              0              0  ...  16.636703     120  1349
# 3              1              0              0  ...  10.739832     108  1562
# 4              1              0              0  ...  12.522300      82  1600
#
# [5 rows x 30 columns]

# %%
scaler = StandardScaler()
col_names= ['temp', 'hum', 'windspeed','cnt','casual']
df_2[col_names] = scaler.fit_transform(df_2[col_names])

# %%
df_2.head()
# Out:
#    season_Spring  season_Summer  season_Winter  ...  windspeed    casual       cnt
# 0              1              0              0  ...  -0.387833 -0.755455 -1.820972
# 1              1              0              0  ...   0.748899 -1.046996 -1.916078
# 2              1              0              0  ...   0.745931 -1.063031 -1.632827
# 3              1              0              0  ...  -0.389769 -1.080523 -1.522732
# 4              1              0              0  ...  -0.046477 -1.118424 -1.503090
#
# [5 rows x 30 columns]

# %%
X=df_2
y=df_2.pop('cnt')

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)

# %%
r2_score=r2_score(y_test,pred)
r2_score
# Out:
# 0.88913013111781

# %% [markdown]
# We know that higher the R square value then better the model, here we got 88.9% R square value, thus we can say that model is good at prediction.

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))
rmse
# Out:
# 0.3260196865858642

# %% [markdown]
# As we can observe that RMSE value is 0.32. We know that if the RMSE value lies between 0.2 and 0.5 then the Model predicts accurately. Hence we can say conclude that our model predicts accurately
